# %%
import os
import pandas as pd
# import statsmodels.api as sm 
# import sklearn
import matplotlib
import matplotlib.pyplot as plt

pd.set_option('display.max_rows',10)
pd.set_option('display.max_columns',10)
pd.set_option('display.notebook_repr_html',True)
# %matplotlib notebook

matplotlib.style.use('ggplot')

df = pd.read_csv(os.path.join('..',"data","consumer_complaints.csv.gz"))
# Out:
# //anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (5,11) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#        date_received           product                  sub_product  \
# 0         08/30/2013          Mortgage               Other mortgage
# 1         08/30/2013          Mortgage               Other mortgage
# 2         08/30/2013  Credit reporting                          NaN
# 3         08/30/2013      Student loan     Non-federal student loan
# 4         08/30/2013   Debt collection                  Credit card
# ...              ...               ...                          ...
# 555952    07/01/2014          Mortgage               Other mortgage
# 555953    07/01/2014          Mortgage               Other mortgage
# 555954    07/10/2012          Mortgage  Conventional fixed mortgage
# 555955    04/14/2015   Debt collection                I do not know
# 555956    08/14/2014   Debt collection                I do not know
#
#                                            issue  \
# 0       Loan modification,collection,foreclosure
# 1       Loan servicing, payments, escrow account
# 2         Incorrect information on credit report
# 3                             Repaying your loan
# 4             False statements or representation
# ...                                          ...
# 555952  Loan modification,collection,foreclosure
# 555953  Loan servicing, payments, escrow account
# 555954  Loan modification,collection,foreclosure
# 555955                     Communication tactics
# 555956     Cont'd attempts collect debt not owed
#
#                                 sub_issue     ...      date_sent_to_company  \
# 0                                     NaN     ...                09/03/2013
# 1                                     NaN     ...                09/03/2013
# 2                          Account status     ...                09/18/2013
# 3                      Repaying your loan     ...                08/30/2013
# 4       Attempted to collect wrong amount     ...                08/30/2013
# ...                                   ...     ...                       ...
# 555952                                NaN     ...                07/07/2014
# 555953                                NaN     ...                07/23/2014
# 555954                                NaN     ...                11/18/2013
# 555955         Frequent or repeated calls     ...                04/14/2015
# 555956                   Debt is not mine     ...                08/18/2014
#
#        company_response_to_consumer timely_response consumer_disputed?  \
# 0           Closed with explanation             Yes                Yes
# 1           Closed with explanation             Yes                Yes
# 2           Closed with explanation             Yes                 No
# 3           Closed with explanation             Yes                Yes
# 4           Closed with explanation             Yes                Yes
# ...                             ...             ...                ...
# 555952      Closed with explanation             Yes                 No
# 555953      Closed with explanation              No                 No
# 555954      Closed with explanation             Yes                 No
# 555955            Untimely response              No                 No
# 555956      Closed with explanation             Yes                 No
#
#        complaint_id
# 0            511074
# 1            511080
# 2            510473
# 3            510326
# 4            511067
# ...             ...
# 555952       919529
# 555953       918447
# 555954       114550
# 555955      1329963
# 555956       984116
#
# [555957 rows x 18 columns]

# %%
df.columns
# Out:
# Index(['date_received', 'product', 'sub_product', 'issue', 'sub_issue',
#        'consumer_complaint_narrative', 'company_public_response', 'company',
#        'state', 'zipcode', 'tags', 'consumer_consent_provided',
#        'submitted_via', 'date_sent_to_company', 'company_response_to_consumer',
#        'timely_response', 'consumer_disputed?', 'complaint_id'],
#       dtype='object')

# %%
products_df = df[ ['product', 'complaint_id'] ].groupby('product').count().rename(columns = {'complaint_id': 'count'}).reset_index()

# %% [markdown]
# ### Mortgages are product complained about most

# %%
products_df = products_df.sort_values(by = 'count', ascending = False)

# %%
products_df.plot(x = 'product', y ='count', kind = 'bar')
# Out:
# <img src="data:image/png;base64,...">

# %%
df_mortgage_issues = df[df['product'] == 'Mortgage'][['issue','complaint_id']].groupby('issue').count().rename(columns = {'complaint_id': 'count'}).reset_index()

# %%
df_mortgage_issues = df_mortgage_issues.sort_values(by = 'count', ascending = False)

# %% [markdown]
# ### The most common issues are foreclosure & mortgage broker complaints

# %%
df_mortgage_issues.plot(x='issue', y= 'count', kind = 'bar')
# Out:
# <img src="data:image/png;base64,...">

# %%
df_product = pd.get_dummies(df['product'])

# %%
df_product.head()
# Out:
#               Bank account or service  Consumer Loan  Credit card  \
# complaint_id
# 511074                              0              0            0
# 511080                              0              0            0
# 510473                              0              0            0
# 510326                              0              0            0
# 511067                              0              0            0
#
#               Credit reporting  Debt collection      ...       Mortgage  \
# complaint_id                                         ...
# 511074                       0                0      ...              1
# 511080                       0                0      ...              1
# 510473                       1                0      ...              0
# 510326                       0                0      ...              0
# 511067                       0                1      ...              0
#
#               Other financial service  Payday loan  Prepaid card  Student loan
# complaint_id
# 511074                              0            0             0             0
# 511080                              0            0             0             0
# 510473                              0            0             0             0
# 510326                              0            0             0             1
# 511067                              0            0             0             0
#
# [5 rows x 11 columns]

# %%
df_product = pd.get_dummies(df, columns=['product'])

# %%
df_with_expanded_product = pd.get_dummies(df, columns=['product'])

# %%
df_with_expanded_product.head()
# Out:
#   date_received               sub_product  \
# 0    08/30/2013            Other mortgage
# 1    08/30/2013            Other mortgage
# 2    08/30/2013                       NaN
# 3    08/30/2013  Non-federal student loan
# 4    08/30/2013               Credit card
#
#                                       issue  \
# 0  Loan modification,collection,foreclosure
# 1  Loan servicing, payments, escrow account
# 2    Incorrect information on credit report
# 3                        Repaying your loan
# 4        False statements or representation
#
#                            sub_issue consumer_complaint_narrative  \
# 0                                NaN                          NaN
# 1                                NaN                          NaN
# 2                     Account status                          NaN
# 3                 Repaying your loan                          NaN
# 4  Attempted to collect wrong amount                          NaN
#
#           ...          product_Mortgage product_Other financial service  \
# 0         ...                         1                               0
# 1         ...                         1                               0
# 2         ...                         0                               0
# 3         ...                         0                               0
# 4         ...                         0                               0
#
#   product_Payday loan product_Prepaid card product_Student loan
# 0                   0                    0                    0
# 1                   0                    0                    0
# 2                   0                    0                    0
# 3                   0                    0                    1
# 4                   0                    0                    0
#
# [5 rows x 28 columns]

# %% [markdown]
# ## Complaints by state

# %%
df_mortgage_counts_state = df_with_expanded_product.groupby('state').sum()

# %%
df_mortgage_counts_state
# Out:
#        complaint_id  product_Bank account or service  product_Consumer Loan  \
# state
# AA          7534741                              1.0                    0.0
# AE        214480925                             21.0                   15.0
# AK        587575953                             66.0                   19.0
# AL       5759014037                            600.0                  373.0
# AP        160372554                              7.0                    9.0
# ...             ...                              ...                    ...
# VT        853127304                            128.0                   43.0
# WA      11191050471                           1094.0                  275.0
# WI       5754954013                            572.0                  266.0
# WV       1425126201                            139.0                   72.0
# WY        511873929                             34.0                   22.0
#
#        product_Credit card  product_Credit reporting          ...           \
# state                                                         ...
# AA                     2.0                       0.0          ...
# AE                    24.0                      47.0          ...
# AK                    98.0                     120.0          ...
# AL                   552.0                    1096.0          ...
# AP                    20.0                      28.0          ...
# ...                    ...                       ...          ...
# VT                   156.0                     113.0          ...
# WA                  1284.0                    1829.0          ...
# WI                   993.0                     798.0          ...
# WV                   182.0                     322.0          ...
# WY                    60.0                     123.0          ...
#
#        product_Mortgage  product_Other financial service  product_Payday loan  \
# state
# AA                  4.0                              0.0                  0.0
# AE                 68.0                              0.0                  0.0
# AK                157.0                              0.0                  5.0
# AL               1395.0                              8.0                 79.0
# AP                 39.0                              0.0                  0.0
# ...                 ...                              ...                  ...
# VT                302.0                              0.0                  1.0
# WA               4315.0                             11.0                 48.0
# WI               1955.0                              7.0                 75.0
# WV                342.0                              6.0                  0.0
# WY                151.0                              1.0                  8.0
#
#        product_Prepaid card  product_Student loan
# state
# AA                      0.0                   2.0
# AE                      1.0                  10.0
# AK                      3.0                  17.0
# AL                     27.0                 164.0
# AP                      0.0                   4.0
# ...                     ...                   ...
# VT                      5.0                  55.0
# WA                     50.0                 312.0
# WI                     45.0                 209.0
# WV                      7.0                  83.0
# WY                      0.0                  23.0
#
# [62 rows x 12 columns]

# %%
# read in census data 

df_pop_state = pd.read_csv(os.path.join('..',"data","state_pop_abbreviations.csv"))

# %%
df_pop_state.head()
# Out:
#          State State_         Pop
# 0     .Alabama     AL   4,863,300
# 1      .Alaska    AK      741,894
# 2     .Arizona     AZ   6,931,071
# 3    .Arkansas     AR   2,988,248
# 4  .California     CA  39,250,017

# %%
df_pop_state
# Out:
#              State State_         Pop
# 0         .Alabama     AL   4,863,300
# 1          .Alaska    AK      741,894
# 2         .Arizona     AZ   6,931,071
# 3        .Arkansas     AR   2,988,248
# 4      .California     CA  39,250,017
# ..             ...    ...         ...
# 46       .Virginia     VT   8,411,808
# 47     .Washington     WA   7,288,000
# 48  .West Virginia     WI   1,831,102
# 49      .Wisconsin     WV   5,778,708
# 50        .Wyoming     WY     585,501
#
# [51 rows x 3 columns]

# %%
df_mortgage_by_counts_state = df_with_expanded_product.groupby(['state']).sum()

# %%
df_mortgage_by_counts_state
# Out:
#        complaint_id  product_Bank account or service  product_Consumer Loan  \
# state
# AA          7534741                              1.0                    0.0
# AE        214480925                             21.0                   15.0
# AK        587575953                             66.0                   19.0
# AL       5759014037                            600.0                  373.0
# AP        160372554                              7.0                    9.0
# ...             ...                              ...                    ...
# VT        853127304                            128.0                   43.0
# WA      11191050471                           1094.0                  275.0
# WI       5754954013                            572.0                  266.0
# WV       1425126201                            139.0                   72.0
# WY        511873929                             34.0                   22.0
#
#        product_Credit card  product_Credit reporting          ...           \
# state                                                         ...
# AA                     2.0                       0.0          ...
# AE                    24.0                      47.0          ...
# AK                    98.0                     120.0          ...
# AL                   552.0                    1096.0          ...
# AP                    20.0                      28.0          ...
# ...                    ...                       ...          ...
# VT                   156.0                     113.0          ...
# WA                  1284.0                    1829.0          ...
# WI                   993.0                     798.0          ...
# WV                   182.0                     322.0          ...
# WY                    60.0                     123.0          ...
#
#        product_Mortgage  product_Other financial service  product_Payday loan  \
# state
# AA                  4.0                              0.0                  0.0
# AE                 68.0                              0.0                  0.0
# AK                157.0                              0.0                  5.0
# AL               1395.0                              8.0                 79.0
# AP                 39.0                              0.0                  0.0
# ...                 ...                              ...                  ...
# VT                302.0                              0.0                  1.0
# WA               4315.0                             11.0                 48.0
# WI               1955.0                              7.0                 75.0
# WV                342.0                              6.0                  0.0
# WY                151.0                              1.0                  8.0
#
#        product_Prepaid card  product_Student loan
# state
# AA                      0.0                   2.0
# AE                      1.0                  10.0
# AK                      3.0                  17.0
# AL                     27.0                 164.0
# AP                      0.0                   4.0
# ...                     ...                   ...
# VT                      5.0                  55.0
# WA                     50.0                 312.0
# WI                     45.0                 209.0
# WV                      7.0                  83.0
# WY                      0.0                  23.0
#
# [62 rows x 12 columns]

# %%
#only mortgage complaints by state
#this makes a method list?! I need a dataframe wtf

df_mortgage_state_only = df_mortgage_by_counts_state['product_Mortgage']

# %%
df_mortgage_state_only.add_suffix('_complaints').reset_index()
# Out:
#             state  product_Mortgage
# 0   AA_complaints               4.0
# 1   AE_complaints              68.0
# 2   AK_complaints             157.0
# 3   AL_complaints            1395.0
# 4   AP_complaints              39.0
# ..            ...               ...
# 57  VT_complaints             302.0
# 58  WA_complaints            4315.0
# 59  WI_complaints            1955.0
# 60  WV_complaints             342.0
# 61  WY_complaints             151.0
#
# [62 rows x 2 columns]

# %%
type(df_mortgage_state_only)
# Out:
# pandas.core.series.Series

# %%
# Out:
# pandas.core.series.Series

# %%
#another attempt to turn this series into a Dataframe
df_mortgage_complaints_by_state = pd.Dataframe(series_mortgage_state_only, columns=['state', 'mortgage_complaints'])
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-150-c8f5be6efc1b> in <module>()
#       1 #another attempt to turn this series into a Dataframe
# ----> 2 df_mortgage_complaints_by_state = pd.Dataframe(series_mortgage_state_only, columns=['state', 'mortgage_complaints'])
#       3
#       4
#
# AttributeError: module 'pandas' has no attribute 'Dataframe'

# %%
df_mortgage_by_counts_state = df_with_expanded_product.groupby(['state'], squeeze = True).sum()

# %%
df_mortgage_by_counts_state
# Out:
#        complaint_id  sum_of_complaints_by_product  \
# state
# AA          7534741                       7534750
# AE        214480925                     214481144
# AK        587575953                     587576591
# AL       5759014037                    5759019672
# AP        160372554                     160372707
# ...             ...                           ...
# VT        853127304                     853128247
# WA      11191050471                   11191062025
# WI       5754954013                    5754960138
# WV       1425126201                    1425127658
# WY        511873929                     511874480
#
#        product_Bank account or service  product_Consumer Loan  \
# state
# AA                                 1.0                    0.0
# AE                                21.0                   15.0
# AK                                66.0                   19.0
# AL                               600.0                  373.0
# AP                                 7.0                    9.0
# ...                                ...                    ...
# VT                               128.0                   43.0
# WA                              1094.0                  275.0
# WI                               572.0                  266.0
# WV                               139.0                   72.0
# WY                                34.0                   22.0
#
#        product_Credit card          ...           product_Mortgage  \
# state                               ...
# AA                     2.0          ...                        4.0
# AE                    24.0          ...                       68.0
# AK                    98.0          ...                      157.0
# AL                   552.0          ...                     1395.0
# AP                    20.0          ...                       39.0
# ...                    ...          ...                        ...
# VT                   156.0          ...                      302.0
# WA                  1284.0          ...                     4315.0
# WI                   993.0          ...                     1955.0
# WV                   182.0          ...                      342.0
# WY                    60.0          ...                      151.0
#
#        product_Other financial service  product_Payday loan  \
# state
# AA                                 0.0                  0.0
# AE                                 0.0                  0.0
# AK                                 0.0                  5.0
# AL                                 8.0                 79.0
# AP                                 0.0                  0.0
# ...                                ...                  ...
# VT                                 0.0                  1.0
# WA                                11.0                 48.0
# WI                                 7.0                 75.0
# WV                                 6.0                  0.0
# WY                                 1.0                  8.0
#
#        product_Prepaid card  product_Student loan
# state
# AA                      0.0                   2.0
# AE                      1.0                  10.0
# AK                      3.0                  17.0
# AL                     27.0                 164.0
# AP                      0.0                   4.0
# ...                     ...                   ...
# VT                      5.0                  55.0
# WA                     50.0                 312.0
# WI                     45.0                 209.0
# WV                      7.0                  83.0
# WY                      0.0                  23.0
#
# [62 rows x 13 columns]

# %%
df_mortgage_by_counts_state['product_Mortgage'].plot(kind = "bar")
# Out:
# <img src="data:image/png;base64,...">

# %%
type(df_mortgage_counts_by_state['product_Mortgage'])

# %%
df_mortgage_counts_by_state['product_Mortgage'].to_frame()

# %%
df_counts_by_state = df_with_expanded_product.groupby(['state']).count()

# %%
df_counts_by_state

# %%
df_mortgage_by_counts_state['product_Payday loan'].plot(kind = "bar")

# %%
df_mortgage_by_counts_state['product_Credit card'].plot(kind = "bar")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-17-56ad3d6bc3af> in <module>()
# ----> 1 df_mortgage_by_counts_state['product_Credit card'].plot(kind = "bar")
#
# NameError: name 'df_mortgage_by_counts_state' is not defined

# %%
df_mortgage_by_counts_state = df_with_expanded_product.groupby(['state'], squeeze = True).sum()

# %% [markdown]
# ## Group by Product

# %%
#this is creating a new column that is summing something unknown ???!!!
df_product['sum_of_complaints_by_product'] = df_product.sum(axis=1)

# %%
df_product
# Out:
#        date_received                  sub_product  \
# 0         08/30/2013               Other mortgage
# 1         08/30/2013               Other mortgage
# 2         08/30/2013                          NaN
# 3         08/30/2013     Non-federal student loan
# 4         08/30/2013                  Credit card
# ...              ...                          ...
# 555952    07/01/2014               Other mortgage
# 555953    07/01/2014               Other mortgage
# 555954    07/10/2012  Conventional fixed mortgage
# 555955    04/14/2015                I do not know
# 555956    08/14/2014                I do not know
#
#                                            issue  \
# 0       Loan modification,collection,foreclosure
# 1       Loan servicing, payments, escrow account
# 2         Incorrect information on credit report
# 3                             Repaying your loan
# 4             False statements or representation
# ...                                          ...
# 555952  Loan modification,collection,foreclosure
# 555953  Loan servicing, payments, escrow account
# 555954  Loan modification,collection,foreclosure
# 555955                     Communication tactics
# 555956     Cont'd attempts collect debt not owed
#
#                                 sub_issue consumer_complaint_narrative  \
# 0                                     NaN                          NaN
# 1                                     NaN                          NaN
# 2                          Account status                          NaN
# 3                      Repaying your loan                          NaN
# 4       Attempted to collect wrong amount                          NaN
# ...                                   ...                          ...
# 555952                                NaN                          NaN
# 555953                                NaN                          NaN
# 555954                                NaN                          NaN
# 555955         Frequent or repeated calls                          NaN
# 555956                   Debt is not mine                          NaN
#
#                    ...              product_Other financial service  \
# 0                  ...                                            0
# 1                  ...                                            0
# 2                  ...                                            0
# 3                  ...                                            0
# 4                  ...                                            0
# ...                ...                                          ...
# 555952             ...                                            0
# 555953             ...                                            0
# 555954             ...                                            0
# 555955             ...                                            0
# 555956             ...                                            0
#
#        product_Payday loan product_Prepaid card product_Student loan  \
# 0                        0                    0                    0
# 1                        0                    0                    0
# 2                        0                    0                    0
# 3                        0                    0                    1
# 4                        0                    0                    0
# ...                    ...                  ...                  ...
# 555952                   0                    0                    0
# 555953                   0                    0                    0
# 555954                   0                    0                    0
# 555955                   0                    0                    0
# 555956                   0                    0                    0
#
#        sum_of_complaints_by_product
# 0                            511075
# 1                            511081
# 2                            510474
# 3                            510327
# 4                            511068
# ...                             ...
# 555952                       919530
# 555953                       918448
# 555954                       114551
# 555955                      1329964
# 555956                       984117
#
# [555957 rows x 29 columns]

# %%
mortgage_issues = df_with_expanded_product[ ['product_Mortgage', 'complaint_id'] ].groupby('issue').count()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-190-5ecddb90b0e3> in <module>()
# ----> 1 mortgage_issues = df_with_expanded_product[ ['product_Mortgage', 'complaint_id'] ].groupby('issue').count()
#
# //anaconda/lib/python3.5/site-packages/pandas/core/generic.py in groupby(self, by, axis, level, as_index, sort, group_keys, squeeze, **kwargs)
#    4414         return groupby(self, by=by, axis=axis, level=level, as_index=as_index,
#    4415                        sort=sort, group_keys=group_keys, squeeze=squeeze,
# -> 4416                        **kwargs)
#    4417
#    4418     def asfreq(self, freq, method=None, how=None, normalize=False,
#
# //anaconda/lib/python3.5/site-packages/pandas/core/groupby.py in groupby(obj, by, **kwds)
#    1697         raise TypeError('invalid type: %s' % type(obj))
#    1698
# -> 1699     return klass(obj, by, **kwds)
#    1700
#    1701
#
# //anaconda/lib/python3.5/site-packages/pandas/core/groupby.py in __init__(self, obj, keys, axis, level, grouper, exclusions, selection, as_index, sort, group_keys, squeeze, **kwargs)
#     390                                                     level=level,
#     391                                                     sort=sort,
# --> 392                                                     mutated=self.mutated)
#     393
#     394         self.obj = obj
#
# //anaconda/lib/python3.5/site-packages/pandas/core/groupby.py in _get_grouper(obj, key, axis, level, sort, mutated)
#    2688                 in_axis, name, level, gpr = False, None, gpr, None
#    2689             else:
# -> 2690                 raise KeyError(gpr)
#    2691         elif isinstance(gpr, Grouper) and gpr.key is not None:
#    2692             # Add key to exclusions
#
# KeyError: 'issue'

# %%
df_with_expanded_product.columns
# Out:
# Index(['date_received', 'sub_product', 'issue', 'sub_issue',
#        'consumer_complaint_narrative', 'company_public_response', 'company',
#        'state', 'zipcode', 'tags', 'consumer_consent_provided',
#        'submitted_via', 'date_sent_to_company', 'company_response_to_consumer',
#        'timely_response', 'consumer_disputed?', 'complaint_id',
#        'product_Bank account or service', 'product_Consumer Loan',
#        'product_Credit card', 'product_Credit reporting',
#        'product_Debt collection', 'product_Money transfers',
#        'product_Mortgage', 'product_Other financial service',
#        'product_Payday loan', 'product_Prepaid card', 'product_Student loan'],
#       dtype='object')
