# %%
import os

import pandas as pd
pd.set_option('display.max_rows', 10)
pd.set_option('display.notebook_repr_html', True)
pd.set_option('display.max_columns', 10)

# %%
df = pd.read_csv(os.path.join('datasets', 'dataset-06-storms.csv'),encoding = "latin")
# Out:
# //anaconda/lib/python3.5/site-packages/IPython/core/interactiveshell.py:2717: DtypeWarning: Columns (2,9,10,11,12,16,17,27,28,29,30,35) have mixed types. Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
df
# Out:
#         STATE__            BGN_DATE     BGN_TIME TIME_ZONE  COUNTY    ...     \
# 0           1.0   4/18/1950 0:00:00          130       CST    97.0    ...
# 1           1.0   4/18/1950 0:00:00          145       CST     3.0    ...
# 2           1.0   2/20/1951 0:00:00         1600       CST    57.0    ...
# 3           1.0    6/8/1951 0:00:00          900       CST    89.0    ...
# 4           1.0  11/15/1951 0:00:00         1500       CST    43.0    ...
# ...         ...                 ...          ...       ...     ...    ...
# 902292     56.0  11/30/2011 0:00:00  10:30:00 PM       MST     7.0    ...
# 902293     30.0  11/10/2011 0:00:00  02:48:00 PM       MST     9.0    ...
# 902294      2.0   11/8/2011 0:00:00  02:58:00 PM       AKS   213.0    ...
# 902295      2.0   11/9/2011 0:00:00  10:21:00 AM       AKS   202.0    ...
# 902296      1.0  11/28/2011 0:00:00  08:00:00 PM       CST     6.0    ...
#
#        LONGITUDE LATITUDE_E LONGITUDE_  \
# ...

# %%
df.describe()
# Out:
# //anaconda/lib/python3.5/site-packages/numpy/lib/function_base.py:3834: RuntimeWarning: Invalid value encountered in percentile
#   RuntimeWarning)
#              STATE__         COUNTY      BGN_RANGE  COUNTY_END  COUNTYENDN  \
# count  902297.000000  902297.000000  902297.000000    902297.0         0.0
# mean       31.200958     100.642905       1.483889         0.0         NaN
# std        16.570178     107.276509       5.481574         0.0         NaN
# min         1.000000       0.000000       0.000000         0.0         NaN
# 25%        19.000000      31.000000       0.000000         0.0         NaN
# 50%        30.000000      75.000000       0.000000         0.0         NaN
# 75%        45.000000     131.000000       1.000000         0.0         NaN
# max        95.000000     873.000000    3749.000000         0.0         NaN
#
#            ...             LATITUDE      LONGITUDE     LATITUDE_E  \
# count      ...        902250.000000  902297.000000  902257.000000
# ...

# %%
df.plot.line()

# %%
pd.tools.plotting.scatter_matrix(df[['STATE_','COUNTY']]
# Out:
#   File "<ipython-input-30-dc6d71ae2305>", line 1
#     pd.tools.plotting.scatter_matrix(df[['STATE_','COUNTY']]
#                                                             ^
# SyntaxError: unexpected EOF while parsing

# %%
pd.isnull()
# Out:
# ['STATE__',
#  'BGN_DATE',
#  'BGN_TIME',
#  'TIME_ZONE',
#  'COUNTY',
#  'COUNTYNAME',
#  'STATE',
#  'EVTYPE',
#  'BGN_RANGE',
#  'BGN_AZI',
#  'BGN_LOCATI',
#  'END_DATE',
#  'END_TIME',
#  'COUNTY_END',
#  'COUNTYENDN',
#  'END_RANGE',
#  'END_AZI',
#  'END_LOCATI',
#  'LENGTH',
#  'WIDTH',
#  'F',
#  'MAG',
#  'FATALITIES',
#  'INJURIES',
#  'PROPDMG',
#  'PROPDMGEXP',
#  'CROPDMG',
#  'CROPDMGEXP',
#  'WFO',
#  'STATEOFFIC',
#  'ZONENAMES',
#  'LATITUDE',
#  'LONGITUDE',
#  'LATITUDE_E',
#  'LONGITUDE_',
#  'REMARKS',
#  'REFNUM']

# %%
df['FATALITIES'].value_counts()
# Out:
# 0.0      895323
# 1.0        5010
# 2.0         996
# 3.0         314
# 4.0         166
#           ...
# 36.0          1
# 34.0          1
# 158.0         1
# 26.0          1
# 583.0         1
# Name: FATALITIES, dtype: int64

# %%
pd.isnull(df)
# Out:
#        STATE__ BGN_DATE BGN_TIME TIME_ZONE COUNTY  ...   LONGITUDE LATITUDE_E  \
# 0        False    False    False     False  False  ...       False      False
# 1        False    False    False     False  False  ...       False      False
# 2        False    False    False     False  False  ...       False      False
# 3        False    False    False     False  False  ...       False      False
# 4        False    False    False     False  False  ...       False      False
# ...        ...      ...      ...       ...    ...  ...         ...        ...
# 902292   False    False    False     False  False  ...       False      False
# 902293   False    False    False     False  False  ...       False      False
# 902294   False    False    False     False  False  ...       False      False
# 902295   False    False    False     False  False  ...       False      False
# 902296   False    False    False     False  False  ...       False      False
#
#        LONGITUDE_ REMARKS REFNUM
# ...

# %%
df.head()
# Out:
#    STATE__            BGN_DATE BGN_TIME TIME_ZONE  COUNTY  ...   LONGITUDE  \
# 0      1.0   4/18/1950 0:00:00      130       CST    97.0  ...      8812.0
# 1      1.0   4/18/1950 0:00:00      145       CST     3.0  ...      8755.0
# 2      1.0   2/20/1951 0:00:00     1600       CST    57.0  ...      8742.0
# 3      1.0    6/8/1951 0:00:00      900       CST    89.0  ...      8626.0
# 4      1.0  11/15/1951 0:00:00     1500       CST    43.0  ...      8642.0
#
#   LATITUDE_E LONGITUDE_  REMARKS REFNUM
# 0     3051.0     8806.0      NaN    1.0
# 1        0.0        0.0      NaN    2.0
# 2        0.0        0.0      NaN    3.0
# 3        0.0        0.0      NaN    4.0
# 4        0.0        0.0      NaN    5.0
#
# [5 rows x 37 columns]

# %%
df['INJURIES'].value_counts()
# Out:
# 0.0       884693
# 1.0         7756
# 2.0         3134
# 3.0         1552
# 4.0          931
#            ...
# 144.0          1
# 143.0          1
# 142.0          1
# 138.0          1
# 1700.0         1
# Name: INJURIES, dtype: int64

# %%
df.corr()
# Out:
#              STATE__    COUNTY  BGN_RANGE  COUNTY_END  COUNTYENDN    ...     \
# STATE__     1.000000  0.306231   0.045905         NaN         NaN    ...
# COUNTY      0.306231  1.000000   0.054419         NaN         NaN    ...
# BGN_RANGE   0.045905  0.054419   1.000000         NaN         NaN    ...
# COUNTY_END       NaN       NaN        NaN         NaN         NaN    ...
# COUNTYENDN       NaN       NaN        NaN         NaN         NaN    ...
# ...              ...       ...        ...         ...         ...    ...
# LATITUDE   -0.006642  0.034407   0.071263         NaN         NaN    ...
# LONGITUDE  -0.024199  0.097044   0.089530         NaN         NaN    ...
# LATITUDE_E -0.029509  0.007791   0.111696         NaN         NaN    ...
# LONGITUDE_ -0.039056  0.032864   0.123731         NaN         NaN    ...
# REFNUM      0.090742  0.017981   0.115187         NaN         NaN    ...
#
#             LATITUDE  LONGITUDE  LATITUDE_E  LONGITUDE_    REFNUM
# ...

# %%
df.dropna()
# Out:
# Empty DataFrame
# Columns: [STATE__, BGN_DATE, BGN_TIME, TIME_ZONE, COUNTY, COUNTYNAME, STATE, EVTYPE, BGN_RANGE, BGN_AZI, BGN_LOCATI, END_DATE, END_TIME, COUNTY_END, COUNTYENDN, END_RANGE, END_AZI, END_LOCATI, LENGTH, WIDTH, F, MAG, FATALITIES, INJURIES, PROPDMG, PROPDMGEXP, CROPDMG, CROPDMGEXP, WFO, STATEOFFIC, ZONENAMES, LATITUDE, LONGITUDE, LATITUDE_E, LONGITUDE_, REMARKS, REFNUM]
# Index: []
#
# [0 rows x 37 columns]

# %%
df.dropna(axis=1)
# Out:
#         STATE__            BGN_DATE     BGN_TIME TIME_ZONE  COUNTY    ...     \
# 0           1.0   4/18/1950 0:00:00          130       CST    97.0    ...
# 1           1.0   4/18/1950 0:00:00          145       CST     3.0    ...
# 2           1.0   2/20/1951 0:00:00         1600       CST    57.0    ...
# 3           1.0    6/8/1951 0:00:00          900       CST    89.0    ...
# 4           1.0  11/15/1951 0:00:00         1500       CST    43.0    ...
# ...         ...                 ...          ...       ...     ...    ...
# 902292     56.0  11/30/2011 0:00:00  10:30:00 PM       MST     7.0    ...
# 902293     30.0  11/10/2011 0:00:00  02:48:00 PM       MST     9.0    ...
# 902294      2.0   11/8/2011 0:00:00  02:58:00 PM       AKS   213.0    ...
# 902295      2.0   11/9/2011 0:00:00  10:21:00 AM       AKS   202.0    ...
# 902296      1.0  11/28/2011 0:00:00  08:00:00 PM       CST     6.0    ...
#
#        PROPDMG CROPDMG  LONGITUDE  LONGITUDE_    REFNUM
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-50-72b44c061663> in <module>()
# ----> 1 df.shape()
#
# TypeError: 'tuple' object is not callable

# %%
df.corr()
# Out:
#              STATE__    COUNTY  BGN_RANGE  COUNTY_END  COUNTYENDN    ...     \
# STATE__     1.000000  0.306231   0.045905         NaN         NaN    ...
# COUNTY      0.306231  1.000000   0.054419         NaN         NaN    ...
# BGN_RANGE   0.045905  0.054419   1.000000         NaN         NaN    ...
# COUNTY_END       NaN       NaN        NaN         NaN         NaN    ...
# COUNTYENDN       NaN       NaN        NaN         NaN         NaN    ...
# ...              ...       ...        ...         ...         ...    ...
# LATITUDE   -0.006642  0.034407   0.071263         NaN         NaN    ...
# LONGITUDE  -0.024199  0.097044   0.089530         NaN         NaN    ...
# LATITUDE_E -0.029509  0.007791   0.111696         NaN         NaN    ...
# LONGITUDE_ -0.039056  0.032864   0.123731         NaN         NaN    ...
# REFNUM      0.090742  0.017981   0.115187         NaN         NaN    ...
#
#             LATITUDE  LONGITUDE  LATITUDE_E  LONGITUDE_    REFNUM
# ...

# %%
df.sort_values("FATALITIES")
# Out:
#         STATE__           BGN_DATE     BGN_TIME TIME_ZONE  COUNTY    ...     \
# 0           1.0  4/18/1950 0:00:00          130       CST    97.0    ...
# 600640     55.0   7/8/2005 0:00:00  07:30:00 PM       CST   109.0    ...
# 600641     55.0   7/8/2005 0:00:00  07:30:00 PM       CST    93.0    ...
# 600642     55.0  7/17/2005 0:00:00  11:00:00 AM       CST    33.0    ...
# 600643     55.0  7/17/2005 0:00:00  10:08:00 PM       CST    35.0    ...
# ...         ...                ...          ...       ...     ...    ...
# 355127     17.0  7/28/1999 0:00:00  11:00:00 AM       CST     5.0    ...
# 148851     48.0  5/11/1953 0:00:00         1610       CST   309.0    ...
# 68669      26.0   6/8/1953 0:00:00         1930       CST    49.0    ...
# 862633     29.0  5/22/2011 0:00:00  04:40:00 PM       CST    97.0    ...
# 198703     17.0  7/12/1995 0:00:00         1100       CST     0.0    ...
#
#        LONGITUDE LATITUDE_E LONGITUDE_  \
# 0         8812.0     3051.0     8806.0
# ...

# %%
df.CROPDMG.map({'$': 1. / (10 ** 6), '$M': 1.})

# %%
df[["FATALITIES","EVTYPE"]]

# %%
df.head()
